# %%
import pandas as pd
import missingno as msno
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('importance.csv')
df.head()
# Out:
#    Path Token Count  Average Domain Token  Entropy URL  Charcomp Vowels  \
# 0                12                   5.5     0.676804               15
# 1                12                   5.0     0.715629               12
# 2                11                   4.0     0.677701               16
# 3                 7                   4.5     0.696067               15
# 4                10                   6.0     0.747202                9
#
#    Charcomp Ace  Path Url Ratio  Domain URL Ratio  Symbol Count URL URL Type
# 0             7        0.762500          0.150000                 6   benign
# 1             8        0.692308          0.217949                 7   benign
# 2            11        0.760563          0.126761                 8   benign
# 3            10        0.734375          0.156250                 5   benign
# 4             5        0.705882          0.191176                 9   benign

# %%
df['URL Type'].unique()
# Out:
# array(['benign', 'Defacement', 'malware', 'phishing', 'spam'],
#       dtype=object)

# %%
mask = df.isnull()
total = mask.sum()
percent = 100*mask.mean()

missing_data = pd.concat([total, percent], axis=1,join='outer',
                         keys=['count_missing', 'perc_missing'])
missing_data.sort_values(by='perc_missing', ascending=False, inplace=True)
missing_data
# Out:
#                       count_missing  perc_missing
# Path Token Count                  0           0.0
# Average Domain Token              0           0.0
# Entropy URL                       0           0.0
# Charcomp Vowels                   0           0.0
# Charcomp Ace                      0           0.0
# Path Url Ratio                    0           0.0
# Domain URL Ratio                  0           0.0
# Symbol Count URL                  0           0.0
# URL Type                          0           0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36707 entries, 0 to 36706
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Path Token Count      36707 non-null  int64
#  1   Average Domain Token  36707 non-null  float64
#  2   Entropy URL           36707 non-null  float64
#  3   Charcomp Vowels       36707 non-null  int64
#  4   Charcomp Ace          36707 non-null  int64
#  5   Path Url Ratio        36707 non-null  float64
#  6   Domain URL Ratio      36707 non-null  float64
#  7   Symbol Count URL      36707 non-null  int64
#  8   URL Type              36707 non-null  int32
# dtypes: float64(4), int32(1), int64(4)
# memory usage: 2.4 MB

# %%
from sklearn import preprocessing
# creating initial dataframe

le = preprocessing.LabelEncoder()
df['URL Type'] = le.fit_transform(df['URL Type'])
df
# Out:
#        Path Token Count  Average Domain Token  Entropy URL  Charcomp Vowels  \
# 0                    12              5.500000     0.676804               15
# 1                    12              5.000000     0.715629               12
# 2                    11              4.000000     0.677701               16
# 3                     7              4.500000     0.696067               15
# 4                    10              6.000000     0.747202                9
# ...                 ...                   ...          ...              ...
# 36702                14              5.750000     0.690555               20
# 36703                13              3.750000     0.665492               24
# 36704                27              6.666666     0.656807               41
# 36705                13              4.333334     0.725963               15
# 36706                25              6.666666     0.674351               35
#
#        Charcomp Ace  Path Url Ratio  Domain URL Ratio  Symbol Count URL  \
# 0                 7        0.762500          0.150000                 6
# 1                 8        0.692308          0.217949                 7
# 2                11        0.760563          0.126761                 8
# 3                10        0.734375          0.156250                 5
# 4                 5        0.705882          0.191176                 9
# ...             ...             ...               ...               ...
# 36702            24        0.773973          0.178082                19
# 36703            23        0.829932          0.122449                23
# 36704            34        0.882114          0.089431                26
# 36705            13        0.810345          0.129310                14
# 36706            31        0.872247          0.096916                24
#
#        URL Type
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ...         ...
# 36702         4
# 36703         4
# 36704         4
# 36705         4
# 36706         4
#
# [36707 rows x 9 columns]

# %%
df['URL Type'].unique()
# Out:
# array([1, 0, 2, 3, 4])

# %%
df['Path Token Count'].unique()
# Out:
# array([12, 11,  7, 10,  9, 13,  6, 19, 16, 17,  8,  3, 15, 14,  5, 22,  4,
#        18, 21, 45, 20, 35, 23, 24, 44, 29, 25, 26, 28, 36,  2, 31, 40, 68,
#        51, 27,  1, 38, 34, 33, 32, 30,  0], dtype=int64)

# %%
df.to_csv('num.csv')

# %%
df1=pd.read_csv('num.csv')
df1.head()
# Out:
#    path_token_count  average_domain_token  entropy_url  charcompvowels  \
# 0                12                   5.5     0.676804              15
# 1                12                   5.0     0.715629              12
# 2                11                   4.0     0.677701              16
# 3                 7                   4.5     0.696067              15
# 4                10                   6.0     0.747202               9
#
#    charcompace  path_url_ratio  domain_url_ratio  symbol_count_url  url_type
# 0            7        0.762500          0.150000                 6         1
# 1            8        0.692308          0.217949                 7         1
# 2           11        0.760563          0.126761                 8         1
# 3           10        0.734375          0.156250                 5         1
# 4            5        0.705882          0.191176                 9         1

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36707 entries, 0 to 36706
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   path_token_count      36707 non-null  int64
#  1   average_domain_token  36707 non-null  float64
#  2   entropy_url           36707 non-null  float64
#  3   charcompvowels        36707 non-null  int64
#  4   charcompace           36707 non-null  int64
#  5   path_url_ratio        36707 non-null  float64
#  6   domain_url_ratio      36707 non-null  float64
#  7   symbol_count_url      36707 non-null  int64
#  8   url_type              36707 non-null  int64
# dtypes: float64(4), int64(5)
# memory usage: 2.5 MB
